# %%
# menghitung rumus segitiga
alas = 10
tinggi = 10
luas = (alas * tinggi) / 2
print(luas)
# Out:
# 50.0

# %%
nama_mhs1 = "Grace"
nama_mhs2 = "wulan"
nama_mhs3 = "Anjelo"
print(nama_mhs1)
print(nama_mhs2)
print(nama_mhs3)
print(nama_mhs1, nama_mhs2, nama_mhs3, "adalah anak bapak Petrus")
# Out:
# Grace
# wulan
# Anjelo
# Grace wulan Anjelo adalah anak bapak Petrus

# %%
# menghitung jumlah detik dalam sehari
jumlah = 24 * 60 * 60
print(jumlah)
# Out:
# 86400
